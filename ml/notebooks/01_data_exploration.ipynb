# %%
import yfinance as yf
import pandas as pd
import matplotlib.pyplot as plt
# Out:
# /Users/omi/ai-portfolio-risk-analyzer/venv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
tickers = ["AAPL", "MSFT", "GOOG"]

data = yf.download(tickers, start="2020-01-01", end="2024-01-01")["Close"]

data.head()
# Out:
# [*********************100%***********************]  3 of 3 completed
#
# 1 Failed download:
# ['AAPL']: OperationalError('database is locked')
# Ticker      AAPL       GOOG        MSFT
# Date
# 2020-01-02   NaN  67.811760  152.158401
# 2020-01-03   NaN  67.478996  150.263763
# 2020-01-06   NaN  69.142830  150.652161
# 2020-01-07   NaN  69.099693  149.278595
# 2020-01-08   NaN  69.644226  151.656342

# %%
data.plot(figsize=(10,5))
plt.title("Stock Prices")
plt.show()

# %%
returns = data.pct_change().dropna()

returns.head()
# Out:
# /var/folders/tm/k9_jd5t950zfllx1tt8rmjq40000gn/T/ipykernel_26954/3273100650.py:1: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Either fill in any non-leading NA values prior to calling pct_change or specify 'fill_method=None' to not fill NA values.
#   returns = data.pct_change().dropna()
# Empty DataFrame
# Columns: [AAPL, GOOG, MSFT]
# Index: []
